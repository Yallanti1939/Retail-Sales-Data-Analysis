# %% [markdown]
# # Retail Sales Data Cleaning
#
# This notebook loads the raw CSV, profiles it, removes invalid records, handles missing values, parses timestamps, validates numeric fields, and writes the cleaned dataset.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.data_cleaning import clean_transactions
from src.data_loader import load_csv, profile_dataframe
from src.feature_engineering import add_sales_features

raw_df = load_csv(PROJECT_ROOT / 'data' / 'transaction_data.csv')
profile = profile_dataframe(raw_df)
profile['shape']

# %%
raw_df.head()

# %%
cleaned_df = add_sales_features(clean_transactions(raw_df))
cleaned_df.info()
cleaned_df.describe()

# %%
output_path = PROJECT_ROOT / 'data' / 'cleaned_transaction_data.csv'
cleaned_df.to_csv(output_path, index=False)
output_path
